# %% [markdown]
# import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage as skim
from skimage import io
from skimage.util import crop
import matplotlib.image as mpimg

# %% [markdown]
# definition function

# %%
def thresholding(thresh,img):
    nrow, ncol, ncolor  = img.shape
    new_img = img.copy()
    for i in range(nrow):
        for j in range(ncol):
            if(img[i,j][0]>thresh and img[i,j][1]>thresh and img[i,j][2]>thresh ):
                new_img[i,j] = [255,255,255]
    # plt.imshow(new_img)
    return new_img

# %%
def thresholding_2value(min_th,max_th,img):
    nrow, ncol, ncolor  = img.shape
    new_img = img.copy()
    for i in range(nrow):
        for j in range(ncol):
            if(img[i,j][0]>max_th and img[i,j][1]>max_th and img[i,j][2]>max_th ):
                new_img[i,j] = [255,255,255]
            if(img[i,j][0]<min_th and img[i,j][1]<min_th and img[i,j][2]<min_th ):
                new_img[i,j] = [255,255,255]
    # plt.imshow(new_img)
    return new_img

# %%
def find_length(img,position = True): #input must thresholding before
    nrow, ncol, ncolor  = img.shape
    right_position = []
    left_position = []
    #find all left side
    temp1 = []
    for i in range(nrow):
        for j in range(ncol):
            if(img[i,j][0] < 255 ):
                temp1.append((i,j))
                break
    #find true left side
    temp2 = []
    for i in range(len(temp1)):
        temp2.append(temp1[i][1])
    min_col = np.min(temp2)
    #find center true left side
    temp3 = []
    for i in range(nrow):
        if(img[i,min_col][0] < 255 ):
            temp3.append(i)
    if(len(temp3) == 1):
        min_row = temp3[0]
    elif(len(temp3)%2 == 0):
        min_row = temp3[int(len(temp3)/2)]
    else:
        min_row = temp3[int(len(temp3)/2) + 1]
    left_position = [min_row,min_col]
    # print(left_position)

    #find all right side
    temp1 = []
    for i in range(nrow):
        for j in range(ncol):
            i_inverse = (nrow-1) - i
            j_inverse = (ncol-1) - j
            if(img[i_inverse,j_inverse][0] < 255 ):
                temp1.append((i_inverse,j_inverse))
                break
    #find true right side
    temp2 = []
    for i in range(len(temp1)):
        temp2.append(temp1[i][1])
    max_col = np.max(temp2)
    #find center true right side
    temp3 = []
    for i in range(nrow):
        if(img[i,max_col][0] < 255 ):
            temp3.append(i)
    if(len(temp3) == 1):
        min_row = temp3[0]
    elif(len(temp3)%2 == 0):
        min_row = temp3[int(len(temp3)/2)]
    else:
        min_row = temp3[int(len(temp3)/2) + 1]
    right_position = [min_row,max_col]
    if(position == True):
        print(left_position)
        print(right_position)

    #find length with pythagoras theorem
    base = np.abs(right_position[1] - left_position[1])
    perp = np.abs(left_position[0] - right_position[0])
    length = np.hypot(base, perp)
    # print("length of picture is " , length , str("pixel"))
    return length

# %%
def plot_compare_img(img1,img2):
    plt.figure(figsize=(20,10))
    plt.subplot(121), plt.imshow(img1), plt.axis('off') 
    plt.subplot(122), plt.imshow(img2), plt.axis('off') 
    plt.show()

# %%
def plot_histogram(img):
    _ = plt.hist(img.ravel(), bins = 256, color = 'orange', )
    _ = plt.hist(img[:, :, 0].ravel(), bins = 256, color = 'red', alpha = 0.5)
    _ = plt.hist(img[:, :, 1].ravel(), bins = 256, color = 'Green', alpha = 0.5)
    _ = plt.hist(img[:, :, 2].ravel(), bins = 256, color = 'Blue', alpha = 0.5)
    _ = plt.xlabel('Intensity Value')
    _ = plt.ylabel('Count')
    _ = plt.legend(['Total', 'Red_Channel', 'Green_Channel', 'Blue_Channel'])
    plt.show()

# %%
def pixel_to_cm(pixel):
    return (pixel*0.5)/55

# %% [markdown]
# make measure image

# %%
def_img = io.imread("image\\10.15.2020 Heptane-80%water20%ethanol\\frame 2\\1-45-09 PM\\10.15.2020 (2) 1193.jpg", as_gray=False)
def_img.shape
# Out:
# (1080, 1920, 3)

# %%
measure_im = crop(def_img, ((650, 350), (1500, 300), (0,0)), copy=False)
# print(def_img.shape, measure_im.shape)
plot_compare_img(def_img,measure_im)

# %%
plot_histogram(measure_im)

# %%
thresh_measure_im = thresholding(50,measure_im)
l = find_length(thresh_measure_im)
plot_compare_img(measure_im,thresh_measure_im)
plt.imshow(thresh_measure_im)
print("length of picture is " , l , str("pixel"))
# Out:
# [44, 20]
# [47, 75]
# length of picture is  55.08175741568164 pixel

# %% [markdown]
# 55 pixel = 0.5 cm
#
# x pixel = y cm
#
#
# y cm = (x pixel* 0.5) / 55

# %% [markdown]
# find definition length on 2217 picture

# %%
def_crop_im = crop(def_img, ((110, 825), (710, 400), (0,0)), copy=False)
print(def_img.shape, def_crop_im.shape)
plot_compare_img(def_img,def_crop_im)
# Out:
# (1080, 1920, 3) (145, 810, 3)

# %%
plot_histogram(def_crop_im)

# %%
Tdef_img2 = thresholding(30,def_crop_im)
plot_compare_img(def_crop_im,Tdef_img2)

# %%
ldef = find_length(Tdef_img2)
plt.imshow(Tdef_img2)
print("ldef " , ldef , str("pixel"))
# Out:
# [51, 738]
# [55, 792]
# ldef  54.147945482723536 pixel

# %% [markdown]
# find length on crop value 1 from 1193 to 1255

# %%
number_of_picture = 1193
thresh = 30
template1 = []
l_def = 54.147945482723536
#1255-1193 = 62
for i in range(63):
    if(True) :   
        image = mpimg.imread( "image\\10.15.2020 Heptane-80%water20%ethanol\\frame 2\\1-45-09 PM\\10.15.2020 (2) " + str(number_of_picture + i).zfill(4) + ".jpg" )
        crop_image = crop(image, ((110, 825), (710, 400), (0,0)), copy=False)
        thresh_image = thresholding(thresh,crop_image)
        # plot_compare_img(crop_image,thresh_image)
        length = find_length(thresh_image,False)
        length = length - l_def
        length = int(length)
        template1.append(length)
        # print(i, length)
        # plt.figure()
        # plt.imshow(thresh_image)
        # for i in range(len(template1)/2):
        #     if(template1[i] > 70):

# %%
print(template1)
print(len(template1))
# Out:
# [0, 0, 0, 0, 1, 3, 6, 9, 11, 12, 17, 20, 24, 27, 31, 35, 40, 44, 47, 52, 55, 58, 63, 68, 71, 76, 81, 85, 88, 93, 96, 95, 106, 109, 113, 117, 120, 125, 130, 133, 137, 141, 144, 147, 150, 155, 159, 165, 166, 171, 175, 180, 181, 188, 191, 194, 199, 199, 202, 208, 212, 216, 220]
# 63

# %% [markdown]
# find length on crop value 2 from 1256 to 2064

# %%
image = mpimg.imread( "image\\10.15.2020 Heptane-80%water20%ethanol\\frame 2\\1-45-09 PM\\10.15.2020 (2) " + str(2064).zfill(4) + ".jpg" )
crop_image = crop(image, ((110, 840), (400, 400), (0,0)), copy=False)
plot_compare_img(image,crop_image)

# %%
number_of_picture = 1256
thresh = 30
template2 = []
l_def = 54.147945482723536
#2064-1256 = 808
for i in range(809):
    if( True) :
        image = mpimg.imread( "image\\10.15.2020 Heptane-80%water20%ethanol\\frame 2\\1-45-09 PM\\10.15.2020 (2) " + str(number_of_picture + i).zfill(4) + ".jpg" )
        crop_image = crop(image, ((110, 840), (400, 400), (0,0)), copy=False)
        if(True):
            thresh_image = thresholding(thresh,crop_image)
        else:
            thresh_image = thresholding(40,crop_image)
        # plot_compare_img(crop_image,thresh_image)
        # print(i)
        length = find_length(thresh_image,False)
        length = length - l_def
        length = int(length)
        template2.append(length)
        # print(i, length)
        # plt.figure()
        # plt.imshow(thresh_image)

# %%
print(template2)
print(len(template2))
# Out:
# [222, 228, 231, 235, 239, 242, 246, 248, 252, 255, 258, 262, 265, 269, 272, 274, 279, 281, 285, 288, 291, 294, 296, 296, 304, 307, 311, 314, 318, 321, 319, 326, 329, 330, 336, 339, 342, 345, 347, 351, 353, 357, 361, 363, 366, 368, 368, 375, 379, 381, 384, 385, 389, 392, 395, 398, 401, 404, 407, 409, 413, 415, 418, 421, 425, 426, 429, 432, 435, 437, 440, 442, 445, 448, 451, 453, 457, 459, 461, 461, 467, 470, 474, 476, 479, 481, 483, 486, 488, 491, 493, 496, 498, 501, 504, 506, 509, 511, 513, 516, 518, 521, 523, 526, 529, 531, 534, 536, 539, 541, 543, 546, 548, 549, 553, 554, 556, 559, 562, 563, 567, 569, 571, 572, 575, 578, 581, 582, 585, 588, 588, 591, 594, 596, 598, 600, 603, 606, 607, 610, 611, 614, 617, 619, 621, 623, 625, 628, 630, 632, 634, 637, 638, 641, 643, 645, 648, 650, 652, 654, 656, 658, 660, 662, 664, 666, 669, 671, 672, 676, 678, 680, 682, 684, 685, 688, 689, 692, 693, 695, 697, 698, 701, 703, 706, 708, 709, 712, 713, 715, 717, 719, 720, 723, 723, 726, 729, 730, 732, 735, 736, 738, 740, 742, 744, 746, 748, 750, 752, 754, 756, 757, 758, 760, 762, 765, 766, 768, 769, 772, 774, 776, 777, 779, 779, 783, 785, 787, 788, 790, 792, 794, 796, 798, 799, 801, 802, 804, 807, 808, 809, 811, 812, 815, 817, 818, 820, 821, 822, 824, 827, 829, 829, 831, 831, 834, 836, 838, 839, 842, 842, 844, 846, 848, 850, 851, 853, 854, 856, 858, 859, 861, 862, 864, 866, 867, 869, 871, 872, 874, 875, 877, 879, 880, 881, 883, 885, 886, 888, 889, 891, 892, 894, 895, 895, 899, 900, 902, 903, 904, 907, 908, 909, 911, 912, 914, 914, 916, 918, 920, 920, 923, 924, 925, 926, 927, 930, 930, 932, 934, 935, 936, 937, 939, 940, 941, 942, 943, 944, 946, 947, 948, 949, 950, 951, 952, 953, 954, 955, 956, 957, 958, 958, 959, 960, 961, 961, 961, 962, 962, 963, 963, 963, 964, 965, 965, 965, 965, 966, 966, 966, 967, 967, 967, 966, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 968, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 968, 968, 968, 968, 967, 967, 968, 967, 967, 968, 968, 967, 967, 968, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 967, 968, 968, 967, 967, 968, 967, 968, 968, 968, 967, 968, 967, 967, 967, 967, 967, 967, 968, 967, 968, 967, 967, 967, 967, 968, 968, 968, 968, 969, 969, 968, 968, 968, 968, 968, 967, 967, 967, 968, 968, 968, 969, 969, 968, 968, 968, 968, 968, 968, 968, 968, 968, 968, 968, 968, 969, 969, 968, 968, 968, 968, 969, 969, 969, 968, 968, 968, 968, 968, 969, 968, 968, 968, 968, 968, 969, 969, 969, 968, 968, 968, 968, 968, 969, 968, 968, 968, 968, 968, 968, 968, 968, 968, 968, 968, 968, 968, 968, 968, 968, 969, 968, 968, 968, 969, 968, 968, 969, 968, 968, 968, 969, 969, 969, 969, 969, 969, 969, 969, 969, 968, 969, 969, 969, 969, 969, 969, 969, 969, 969, 968, 969, 969, 968, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 969, 970, 969, 969, 969, 970, 969, 969, 969, 969, 969, 969, 970, 970, 970, 970, 970, 969, 970, 970, 970, 969, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 970, 971, 971, 970, 971, 970, 971, 970, 971, 971, 971, 971, 970, 970, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 971, 972, 971, 971, 971, 971, 971, 972, 972, 972, 972, 972, 971, 971, 971, 971, 971, 972, 971, 972, 972, 971, 972, 972, 972, 972, 972, 972, 972, 972, 972, 971, 972, 972, 972, 972, 972, 972, 972, 972, 972, 972, 972, 972, 972, 972, 972, 972, 972, 972, ...
# 809

# %% [markdown]
# concat 2 template and calculate pixel to centimeter

# %%
l_array = np.concatenate((template1,template2), axis=0)
# print(l_array)
# print(type(l_array[1]))
# print(l_array.shape)
l_array = l_array.astype('float32')

#find missing value and set to 0
for i in range(len(l_array)):
    if(l_array[i] < 0 ):
        l_array[i] = 0

for i in range(len(l_array)):
    l_array[i] = pixel_to_cm(l_array[i])

# %%
print(l_array)
# Out:
# [0.         0.         0.         0.         0.00909091 0.02727273
#  0.05454545 0.08181818 0.1        0.10909091 0.15454546 0.18181819
#  0.21818182 0.24545455 0.28181818 0.3181818  0.36363637 0.4
#  0.42727274 0.47272727 0.5        0.5272727  0.57272726 0.6181818
#  0.6454545  0.6909091  0.73636365 0.77272725 0.8        0.8454546
#  0.8727273  0.8636364  0.96363634 0.9909091  1.0272727  1.0636364
#  1.0909091  1.1363636  1.1818181  1.209091   1.2454545  1.2818182
#  1.3090909  1.3363637  1.3636364  1.4090909  1.4454546  1.5
#  1.5090909  1.5545454  1.5909091  1.6363636  1.6454545  1.709091
#  1.7363636  1.7636364  1.8090909  1.8090909  1.8363637  1.8909091
#  1.9272727  1.9636364  2.         2.0181818  2.0727272  2.1
#  2.1363637  2.1727273  2.2        2.2363636  2.2545455  2.290909
#  2.3181818  2.3454545  2.3818183  2.409091   2.4454546  2.4727273
#  2.490909   2.5363636  2.5545454  2.590909   2.6181817  2.6454546
#  2.6727273  2.6909091  2.6909091  2.7636364  2.790909   2.8272727
#  2.8545454  2.8909092  2.918182   2.9        2.9636364  2.990909
#  3.         3.0545454  3.081818   3.1090908  3.1363637  3.1545455
#  3.1909091  3.209091   3.2454545  3.2818182  3.3        3.3272727
#  3.3454545  3.3454545  3.409091   3.4454546  3.4636364  3.490909
#  3.5        3.5363636  3.5636363  3.590909   3.6181817  3.6454546
#  3.6727273  3.7        3.7181818  3.7545455  3.7727273  3.8
#  3.8272727  3.8636363  3.8727272  3.9        3.9272728  3.9545455
#  3.9727273  4.         4.018182   4.0454545  4.072727   4.1
#  4.1181817  4.1545453  4.172727   4.190909   4.190909   4.2454543
#  4.2727275  4.309091   4.327273   4.3545456  4.3727274  4.390909
#  4.418182   4.4363637  4.4636364  4.481818   4.509091   4.5272727
#  4.5545454  4.581818   4.6        4.6272726  4.6454544  4.663636
#  4.690909   4.7090907  4.7363634  4.7545457  4.7818184  4.809091
#  4.827273   4.8545456  4.8727274  4.9        4.918182   4.9363637
#  4.9636364  4.981818   4.990909   5.0272727  5.0363636  5.0545454
#  5.081818   5.109091   5.1181817  5.1545453  5.172727   5.190909
#  5.2        5.2272725  5.2545457  5.2818184  5.2909093  5.318182
#  5.3454547  5.3454547  5.3727274  5.4        5.418182   5.4363637
#  5.4545455  5.481818   5.509091   5.518182   5.5454545  5.5545454
#  5.581818   5.609091   5.6272726  5.6454544  5.663636   5.681818
#  5.7090907  5.7272725  5.7454543  5.7636366  5.7909093  5.8
#  5.827273   5.8454547  5.8636365  5.890909   5.909091   5.927273
#  5.9454546  5.9636364  5.981818   6.         6.018182   6.0363636
#  6.0545454  6.081818   6.1        6.109091   6.1454544  6.163636
#  6.181818   6.2        6.2181816  6.2272725  6.2545457  6.2636366
#  6.2909093  6.3        6.318182   6.336364   6.3454547  6.3727274
#  6.390909   6.418182   6.4363637  6.4454546  6.4727273  6.481818
#  6.5        6.518182   6.5363636  6.5454545  6.572727   6.572727
#  6.6        6.6272726  6.6363635  6.6545453  6.681818   6.690909
#  6.7090907  6.7272725  6.7454543  6.7636366  6.7818184  6.8
#  6.818182   6.836364   6.8545456  6.8727274  6.8818183  6.890909
#  6.909091   6.927273   6.9545455  6.9636364  6.981818   6.990909
#  7.018182   7.0363636  7.0545454  7.0636363  7.081818   7.081818
#  7.1181817  7.1363635  7.1545453  7.163636   7.181818   7.2
#  7.2181816  7.2363634  7.2545457  7.2636366  7.2818184  7.2909093
#  7.309091   7.336364   7.3454547  7.3545456  7.3727274  7.3818183
#  7.409091   7.427273   7.4363637  7.4545455  7.4636364  7.4727273
#  7.490909   7.518182   7.5363636  7.5363636  7.5545454  7.5545454
#  7.581818   7.6        7.6181817  7.6272726  7.6545453  7.6545453
#  7.672727   7.690909   7.7090907  7.7272725  7.7363634  7.7545457
#  7.7636366  7.7818184  7.8        7.809091   7.827273   7.836364
#  7.8545456  7.8727274  7.8818183  7.9        7.918182   7.927273
#  7.9454546  7.9545455  7.9727273  7.990909   8.         8.009091
#  8.027273   8.045455   8.054545   8.072727   8.081819   8.1
#  8.109091   8.127273   8.136364   8.136364   8.172728   8.181818
#  8.2        8.209091   8.218182   8.245455   8.254545   8.263637
#  8.281818   8.290909   8.309091   8.309091   8.327272   8.345454
#  8.363636   8.363636   8.390909   8.4        8.409091   8.418181
#  8.427273   8.454545   8.454545   8.472727   8.490909   8.5
#  8.509091   8.518182   8.536364   8.545455   8.554545   8.563637
#  8.572727   8.581819   8.6        8.609091   8.618182   8.627273
#  8.636364   8.645454   8.654546   8.663636   8.672728   8.681818
#  8.690909   8.7        8.709091   8.709091   8.718182   8.727273
#  8.736363   8.736363   8.736363   8.745455   8.745455   8.754545
#  8.754545   8.754545   8.763637   8.772727   8.772727   8.772727
#  8.772727   8.781818   8.781818   8.781818   8.790909   8.790909
#  8.790909   8.781818   8.790909   8.790909   8.790909   8.790909
#  8.790909   8.790909   8.790909   8.790909   8.790909   8.790909
#  8.790909   8.790909   8.790909   8.790909   8.790909   8.790909
#  8.790909   8.790909   8.790909   8.790909   8.790909   8.790909
#  8.790909   8.790909   8.790909   8.790909   8.790909   8.790909
#  8.790909   8.790909   8.790909   8.790909   8.8        8.790909
#  8.790909   8.790909   8.790909   8.790909   8.790909   8.790909
#  8.790909   8.790909   8.790909   8.790909   8.790909   8.790909
#  8.790909   8.8        8.8        8.8        8.8        8.790909
#  8.790909   8.8        8.790909   8.790909   8.8        8.8
#  8.790909   8.790909   8.8        8.790909   8.790909   8.790909
#  8.790909   8.790909   8.790909   8.790909   8.790909   8.790909
#  8.790909   8.790909   8.790909   8.790909   8.8        8.8
#  8.790909   8.790909   8.8        8.790909   8.8        8.8
#  8.8        8.790909   8.8        8.790909   8.790909   8.790909
#  8.790909   8.790909   8.790909   8.8        8.790909   8.8
#  8.790909   8.790909   8.790909   8.790909   8.8        8.8
#  8.8        8.8        8.809091   8.809091   8.8        8.8
#  8.8        8.8        8.8        8.790909   8.790909   8.790909
#  8.8        8.8        8.8        8.809091   8.809091   8.8
#  8.8        8.8        8.8        8.8        8.8        8.8
#  8.8        8.8        8.8        8.8        8.8        8.809091
#  8.809091   8.8        8.8        8.8        8.8        8.809091
#  8.809091   8.809091   8.8        8.8        8.8        8.8
#  8.8        8.809091   8.8        8.8        8.8        8.8
#  8.8        8.809091   8.809091   8.809091   8.8        8.8
#  8.8        8.8        8.8        8.809091   8.8        8.8
#  8.8        8.8        8.8        8.8        8.8        8.8
#  8.8        8.8        8.8        8.8        8.8        8.8
#  8.8        8.8        8.809091   8.8        8.8        8.8
#  8.809091   8.8        8.8        8.809091   8.8        8.8
#  8.8        8.809091   8.809091   8.809091   8.809091   8.809091
#  8.809091   8.809091   8.809091   8.809091   8.8        8.809091
#  8.809091   8.809091   8.809091   8.809091   8.809091   8.809091
#  8.809091   8.809091   8.8        8.809091   8.809091   8.8
#  8.809091   8.809091   8.809091   8.809091   8.809091   8.809091
#  8.809091   8.809091   8.809091   8.809091   8.809091   8.809091
#  8.809091   8.809091   8.809091   8.809091   8.809091   8.809091
#  8.809091   8.809091   8.809091   8.809091   8.809091   8.809091
#  8.809091   8.809091   8.809091   8.809091   8.809091   8.809091
#  8.809091   8.809091   8.809091   8.809091   8.809091   8.809091
#  8.809091   8.809091   8.809091   8.809091   8.809091   8.809091
#  8.818182   8.809091   8.809091   8.809091   8.818182   8.809091
#  8.809091   8.809091   8.809091   8.809091   8.809091   8.818182
#  8.818182   8.818182   8.818182   8.818182   8.809091   8.818182
#  8.818182   8.818182   8.809091   8.818182   8.818182   8.818182
#  8.818182   8.818182   8.818182   8.818182   8.818182   8.818182
#  8.818182   8.818182   8.818182   8.818182   8.818182   8.818182
#  8.818182   8.818182   8.818182   8.818182   8.818182   8.818182
#  8.818182   8.818182   8.818182   8.818182   8.818182   8.818182
#  8.818182   8.818182   8.818182   8.818182   8.818182   8.818182
#  8.818182   8.818182   8.818182   8.818182   8.818182   8.818182
#  8.818182   8.818182   8.818182   8.818182   8.818182   8.818182
#  8.818182   8.818182   8.827272   8.827272   8.818182   8.827272
#  8.818182   8.827272   8.818182   8.827272   8.827272   8.827272
#  8.827272   8.818182   8.818182   8.827272   8.827272   8.827272
#  8.827272   8.827272   8.827272   8.827272   8.827272   8.827272
#  8.827272   8.827272   8.827272   8.827272   8.827272   8.827272
#  8.827272   8.827272   8.827272   8.827272   8.827272   8.827272
#  8.827272   8.827272   8.827272   8.827272   8.827272   8.827272
#  8.827272   8.827272   8.827272   8.827272   8.827272   8.827272
#  8.827272   8.827272   8.827272   8.827272   8.827272   8.827272
#  8.827272   8.827272   8.827272   8.827272   8.827272   8.827272
#  8.827272   8.827272   8.827272   8.827272   8.827272   8.827272
#  8.827272   8.827272   8.827272   8.827272   8.836364   8.827272
#  8.827272   8.827272   8.827272   8.827272   8.836364   8.836364
#  8.836364   8.836364   8.836364   8.827272   8.827272   8.827272
#  8.827272   8.827272   8.836364   8.827272   8.836364   8.836364
#  8.827272   8.836364   8.836364   8.836364   8.836364   8.836364
#  8.836364   8.836364   8.836364   8.836364   8.827272   8.836364
#  8.836364   8.836364   8.836364   8.836364   8.836364   8.836364
#  8.836364   8.836364   8.836364   8.836364   8.836364   8.836364
#  8.836364   8.836364   8.836364   8.836364   8.836364   8.836364
#  8.836364   8.836364   8.836364   8.836364   8.836364   8.836364
#  8.836364   8.836364  ]

# %% [markdown]
# export data to exel

# %%
import pandas as pd

# %%
print(len(l_array))
# Out:
# 872

# %%
data = []
num_img = 1193
for i in range(len(l_array)):
    data.append(( " 10.15.2020 (2) " + str(num_img + i).zfill(4)  ,l_array[i] )) 
# print(data)
dataframe = pd.DataFrame(data, 
             columns=['image_name', 
                      'length(cm)'])
# print(dataframe)
# writing to Excel
datatoexcel = pd.ExcelWriter('Heptanewater-80-20(2)_10.15.2020_1-45-09-PM.xlsx')
# write DataFrame to excel 
dataframe.to_excel(datatoexcel)
#save the excel
datatoexcel.save()

# %%
dataframe.plot(kind='line',x='image_name',y='length(cm)',color='red')
plt.show()
