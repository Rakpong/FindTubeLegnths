# %% [markdown]
# import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage as skim
from skimage import io
from skimage.util import crop
import matplotlib.image as mpimg

# %% [markdown]
# definition function

# %%
def thresholding(thresh,img):
    nrow, ncol, ncolor  = img.shape
    new_img = img.copy()
    for i in range(nrow):
        for j in range(ncol):
            if(img[i,j][0]>thresh and img[i,j][1]>thresh and img[i,j][2]>thresh ):
                new_img[i,j] = [255,255,255]
    # plt.imshow(new_img)
    return new_img

# %%
def thresholding_2value(min_th,max_th,img):
    nrow, ncol, ncolor  = img.shape
    new_img = img.copy()
    for i in range(nrow):
        for j in range(ncol):
            if(img[i,j][0]>max_th and img[i,j][1]>max_th and img[i,j][2]>max_th ):
                new_img[i,j] = [255,255,255]
            if(img[i,j][0]<min_th and img[i,j][1]<min_th and img[i,j][2]<min_th ):
                new_img[i,j] = [255,255,255]
    # plt.imshow(new_img)
    return new_img

# %%
def find_length(img,position = True): #input must thresholding before
    nrow, ncol, ncolor  = img.shape
    right_position = []
    left_position = []
    #find all left side
    temp1 = []
    for i in range(nrow):
        for j in range(ncol):
            if(img[i,j][0] < 255 ):
                temp1.append((i,j))
                break
    #find true left side
    temp2 = []
    for i in range(len(temp1)):
        temp2.append(temp1[i][1])
    min_col = np.min(temp2)
    #find center true left side
    temp3 = []
    for i in range(nrow):
        if(img[i,min_col][0] < 255 ):
            temp3.append(i)
    if(len(temp3) == 1):
        min_row = temp3[0]
    elif(len(temp3)%2 == 0):
        min_row = temp3[int(len(temp3)/2)]
    else:
        min_row = temp3[int(len(temp3)/2) + 1]
    left_position = [min_row,min_col]
    # print(left_position)

    #find all right side
    temp1 = []
    for i in range(nrow):
        for j in range(ncol):
            i_inverse = (nrow-1) - i
            j_inverse = (ncol-1) - j
            if(img[i_inverse,j_inverse][0] < 255 ):
                temp1.append((i_inverse,j_inverse))
                break
    #find true right side
    temp2 = []
    for i in range(len(temp1)):
        temp2.append(temp1[i][1])
    max_col = np.max(temp2)
    #find center true right side
    temp3 = []
    for i in range(nrow):
        if(img[i,max_col][0] < 255 ):
            temp3.append(i)
    if(len(temp3) == 1):
        min_row = temp3[0]
    elif(len(temp3)%2 == 0):
        min_row = temp3[int(len(temp3)/2)]
    else:
        min_row = temp3[int(len(temp3)/2) + 1]
    right_position = [min_row,max_col]
    if(position == True):
        print(left_position)
        print(right_position)

    #find length with pythagoras theorem
    base = np.abs(right_position[1] - left_position[1])
    perp = np.abs(left_position[0] - right_position[0])
    length = np.hypot(base, perp)
    # print("length of picture is " , length , str("pixel"))
    return length

# %%
def plot_compare_img(img1,img2):
    plt.figure(figsize=(20,10))
    plt.subplot(121), plt.imshow(img1), plt.axis('off') 
    plt.subplot(122), plt.imshow(img2), plt.axis('off') 
    plt.show()

# %%
def plot_histogram(img):
    _ = plt.hist(img.ravel(), bins = 256, color = 'orange', )
    _ = plt.hist(img[:, :, 0].ravel(), bins = 256, color = 'red', alpha = 0.5)
    _ = plt.hist(img[:, :, 1].ravel(), bins = 256, color = 'Green', alpha = 0.5)
    _ = plt.hist(img[:, :, 2].ravel(), bins = 256, color = 'Blue', alpha = 0.5)
    _ = plt.xlabel('Intensity Value')
    _ = plt.ylabel('Count')
    _ = plt.legend(['Total', 'Red_Channel', 'Green_Channel', 'Blue_Channel'])
    plt.show()

# %%
def pixel_to_cm(pixel):
    return (pixel*0.5)/55

# %% [markdown]
# make measure image

# %%
def_img = io.imread("image\\10.15.2020 Heptane-80%water20%ethanol\\frame 1\\1-45-02 PM\\10.15.2020 (1) 2217.jpg", as_gray=False)
def_img.shape
# Out:
# (1080, 1920, 3)

# %%
measure_im = crop(def_img, ((650, 350), (1500, 300), (0,0)), copy=False)
# print(def_img.shape, measure_im.shape)
plot_compare_img(def_img,measure_im)

# %%
plot_histogram(measure_im)

# %%
thresh_measure_im = thresholding(50,measure_im)
l = find_length(thresh_measure_im)
plot_compare_img(measure_im,thresh_measure_im)
plt.imshow(thresh_measure_im)
print("length of picture is " , l , str("pixel"))
# Out:
# [49, 20]
# [48, 75]
# length of picture is  55.00909015790027 pixel

# %% [markdown]
# 55 pixel = 0.5 cm
#
# x pixel = y cm
#
#
# y cm = (x pixel* 0.5) / 55

# %% [markdown]
# find definition length on 2217 picture

# %%
def_crop_im = crop(def_img, ((230, 725), (710, 357), (0,0)), copy=False)
print(def_img.shape, def_crop_im.shape)
plot_compare_img(def_img,def_crop_im)
# Out:
# (1080, 1920, 3) (125, 853, 3)

# %%
plot_histogram(def_crop_im)

# %%
Tdef_img2 = thresholding(30,def_crop_im)
plot_compare_img(def_crop_im,Tdef_img2)

# %%
ldef = find_length(Tdef_img2)
plt.imshow(Tdef_img2)
print("ldef " , ldef , str("pixel"))
# Out:
# [71, 724]
# [75, 785]
# ldef  61.1310068623117 pixel

# %% [markdown]
# find length on crop value 1 from 2217 to 2270

# %%
number_of_picture = 2217
thresh = 30
template1 = []
l_def = 61.1310068623117
#2270-2217 = 53
for i in range(54):
    if(True) :   
        image = mpimg.imread( "image\\10.15.2020 Heptane-80%water20%ethanol\\frame 1\\1-45-02 PM\\10.15.2020 (1) " + str(number_of_picture + i).zfill(4) + ".jpg" )
        crop_image = crop(image, ((230, 725), (710, 357), (0,0)), copy=False)
        thresh_image = thresholding(thresh,crop_image)
        # plot_compare_img(crop_image,thresh_image)
        length = find_length(thresh_image,False)
        length = length - l_def
        length = int(length)
        template1.append(length)
        # print(i, length)
        # plt.figure()
        # plt.imshow(thresh_image)
        # for i in range(len(template1)/2):
        #     if(template1[i] > 70):

# %%
print(template1)
print(len(template1))
# Out:
# [0, 4, 4, 5, 8, 13, 17, 22, 25, 33, 34, 27, 43, 48, 46, 57, 67, 73, 79, 82, 86, 91, 96, 99, 105, 109, 115, 119, 124, 127, 132, 136, 139, 141, 145, 153, 157, 161, 165, 165, 174, 176, 182, 185, 192, 194, 198, 202, 205, 210, 214, 218, 223, 223]
# 54

# %% [markdown]
# find length on crop value 2 from 2271 to 3132

# %%
image = mpimg.imread( "image\\10.15.2020 Heptane-80%water20%ethanol\\frame 1\\1-45-02 PM\\10.15.2020 (1) " + str(3132).zfill(4) + ".jpg" )
crop_image = crop(image, ((230, 725), (380, 357), (0,0)), copy=False)
plot_compare_img(image,crop_image)

# %%
number_of_picture = 2271
thresh = 30
template2 = []
l_def = 61.1310068623117
#3132-2271 = 861
for i in range(862):
    if( True) :
        image = mpimg.imread( "image\\10.15.2020 Heptane-80%water20%ethanol\\frame 1\\1-45-02 PM\\10.15.2020 (1) " + str(number_of_picture + i).zfill(4) + ".jpg" )
        crop_image = crop(image, ((230, 725), (380, 357), (0,0)), copy=False)
        if(True):
            thresh_image = thresholding(thresh,crop_image)
        else:
            thresh_image = thresholding(40,crop_image)
        # plot_compare_img(crop_image,thresh_image)
        # print(i)
        length = find_length(thresh_image,False)
        length = length - l_def
        length = int(length)
        template2.append(length)
        # print(i, length)
        # plt.figure()
        # plt.imshow(thresh_image)

# %%
print(template2)
print(len(template2))
# Out:
# [229, 233, 236, 240, 244, 249, 252, 253, 260, 262, 266, 268, 272, 274, 279, 284, 287, 291, 294, 297, 300, 304, 307, 311, 314, 315, 320, 324, 327, 330, 334, 337, 340, 344, 344, 350, 353, 356, 359, 362, 365, 368, 371, 374, 377, 377, 381, 382, 390, 390, 396, 400, 401, 405, 408, 411, 412, 417, 419, 420, 425, 428, 427, 433, 436, 440, 442, 446, 450, 451, 454, 458, 460, 462, 463, 468, 471, 473, 476, 478, 481, 484, 487, 490, 490, 495, 497, 498, 500, 505, 508, 508, 513, 513, 518, 521, 523, 524, 529, 531, 534, 537, 537, 538, 544, 546, 549, 551, 550, 557, 559, 561, 562, 564, 569, 572, 574, 577, 578, 581, 585, 584, 588, 591, 593, 596, 598, 601, 602, 604, 608, 610, 613, 614, 617, 620, 621, 625, 626, 627, 631, 633, 636, 638, 640, 642, 645, 648, 650, 652, 655, 657, 659, 661, 663, 664, 668, 668, 672, 674, 675, 679, 681, 683, 684, 687, 690, 691, 693, 696, 697, 699, 702, 704, 707, 708, 710, 713, 715, 717, 720, 721, 723, 725, 727, 729, 731, 733, 734, 738, 739, 742, 743, 747, 749, 750, 753, 753, 756, 759, 761, 763, 764, 766, 768, 770, 773, 775, 776, 778, 780, 783, 785, 787, 788, 791, 792, 794, 796, 798, 799, 801, 802, 804, 807, 809, 811, 812, 815, 816, 818, 821, 821, 824, 826, 828, 830, 832, 833, 836, 837, 839, 841, 843, 845, 847, 848, 850, 852, 854, 856, 858, 860, 861, 863, 863, 866, 868, 871, 872, 873, 874, 877, 878, 880, 881, 884, 887, 888, 888, 892, 893, 895, 897, 897, 899, 901, 904, 904, 906, 908, 911, 911, 913, 915, 918, 918, 921, 922, 924, 926, 928, 929, 931, 933, 934, 936, 938, 940, 941, 941, 941, 942, 948, 948, 951, 953, 954, 955, 956, 958, 959, 961, 962, 963, 964, 964, 965, 966, 967, 968, 969, 970, 971, 970, 971, 971, 972, 972, 972, 974, 974, 974, 974, 975, 975, 975, 976, 976, 975, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 977, 977, 977, 977, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 977, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 977, 977, 976, 976, 976, 976, 976, 977, 977, 976, 976, 976, 976, 976, 976, 976, 977, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 977, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 977, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 977, 976, 976, 976, 976, 976, 976, 977, 977, 976, 976, 976, 976, 977, 976, 976, 976, 976, 976, 977, 977, 977, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 977, 976, 977, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 977, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 977, 977, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 977, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 977, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, 976, ...
# 862

# %% [markdown]
# concat 2 template and calculate pixel to centimeter

# %%
l_array = np.concatenate((template1,template2), axis=0)
# print(l_array)
# print(type(l_array[1]))
# print(l_array.shape)
l_array = l_array.astype('float32')

#find missing value and set to 0
for i in range(len(l_array)):
    if(l_array[i] < 0 ):
        l_array[i] = 0

for i in range(len(l_array)):
    l_array[i] = pixel_to_cm(l_array[i])

# %%
print(l_array)
# Out:
# [0.         0.03636364 0.03636364 0.04545455 0.07272727 0.11818182
#  0.15454546 0.2        0.22727273 0.3        0.3090909  0.24545455
#  0.3909091  0.43636364 0.4181818  0.5181818  0.6090909  0.6636364
#  0.7181818  0.74545455 0.7818182  0.8272727  0.8727273  0.9
#  0.95454544 0.9909091  1.0454545  1.0818182  1.1272727  1.1545454
#  1.2        1.2363636  1.2636364  1.2818182  1.3181819  1.3909091
#  1.4272727  1.4636364  1.5        1.5        1.5818182  1.6
#  1.6545454  1.6818181  1.7454545  1.7636364  1.8        1.8363637
#  1.8636364  1.9090909  1.9454546  1.9818182  2.0272727  2.0272727
#  2.081818   2.1181817  2.1454546  2.1818182  2.2181818  2.2636364
#  2.290909   2.3        2.3636363  2.3818183  2.418182   2.4363637
#  2.4727273  2.490909   2.5363636  2.581818   2.6090908  2.6454546
#  2.6727273  2.7        2.7272727  2.7636364  2.790909   2.8272727
#  2.8545454  2.8636363  2.909091   2.9454546  2.9727273  3.
#  3.0363636  3.0636363  3.090909   3.1272728  3.1272728  3.1818182
#  3.209091   3.2363636  3.2636364  3.290909   3.3181818  3.3454545
#  3.3727272  3.4        3.4272728  3.4272728  3.4636364  3.4727273
#  3.5454545  3.5454545  3.6        3.6363637  3.6454546  3.6818182
#  3.709091   3.7363636  3.7454545  3.790909   3.8090909  3.8181818
#  3.8636363  3.8909092  3.8818183  3.9363637  3.9636364  4.
#  4.018182   4.0545454  4.090909   4.1        4.1272726  4.163636
#  4.181818   4.2        4.2090907  4.2545457  4.2818184  4.3
#  4.327273   4.3454547  4.3727274  4.4        4.427273   4.4545455
#  4.4545455  4.5        4.518182   4.5272727  4.5454545  4.590909
#  4.6181817  4.6181817  4.663636   4.663636   4.7090907  4.7363634
#  4.7545457  4.7636366  4.809091   4.827273   4.8545456  4.8818183
#  4.8818183  4.890909   4.9454546  4.9636364  4.990909   5.009091
#  5.         5.0636363  5.081818   5.1        5.109091   5.1272726
#  5.172727   5.2        5.2181816  5.2454543  5.2545457  5.2818184
#  5.318182   5.309091   5.3454547  5.3727274  5.390909   5.418182
#  5.4363637  5.4636364  5.4727273  5.490909   5.5272727  5.5454545
#  5.572727   5.581818   5.609091   5.6363635  5.6454544  5.681818
#  5.690909   5.7        5.7363634  5.7545457  5.7818184  5.8
#  5.818182   5.836364   5.8636365  5.890909   5.909091   5.927273
#  5.9545455  5.9727273  5.990909   6.009091   6.0272727  6.0363636
#  6.072727   6.072727   6.109091   6.1272726  6.1363635  6.172727
#  6.190909   6.2090907  6.2181816  6.2454543  6.2727275  6.2818184
#  6.3        6.327273   6.336364   6.3545456  6.3818183  6.4
#  6.427273   6.4363637  6.4545455  6.481818   6.5        6.518182
#  6.5454545  6.5545454  6.572727   6.590909   6.609091   6.6272726
#  6.6454544  6.663636   6.672727   6.7090907  6.7181816  6.7454543
#  6.7545457  6.7909093  6.809091   6.818182   6.8454547  6.8454547
#  6.8727274  6.9        6.918182   6.9363637  6.9454546  6.9636364
#  6.981818   7.         7.0272727  7.0454545  7.0545454  7.072727
#  7.090909   7.1181817  7.1363635  7.1545453  7.163636   7.190909
#  7.2        7.2181816  7.2363634  7.2545457  7.2636366  7.2818184
#  7.2909093  7.309091   7.336364   7.3545456  7.3727274  7.3818183
#  7.409091   7.418182   7.4363637  7.4636364  7.4636364  7.490909
#  7.509091   7.5272727  7.5454545  7.5636363  7.572727   7.6
#  7.609091   7.6272726  7.6454544  7.663636   7.681818   7.7
#  7.7090907  7.7272725  7.7454543  7.7636366  7.7818184  7.8
#  7.818182   7.827273   7.8454547  7.8454547  7.8727274  7.890909
#  7.918182   7.927273   7.9363637  7.9454546  7.9727273  7.981818
#  8.         8.009091   8.036364   8.063637   8.072727   8.072727
#  8.109091   8.118182   8.136364   8.154546   8.154546   8.172728
#  8.190909   8.218182   8.218182   8.236363   8.254545   8.281818
#  8.281818   8.3        8.318182   8.345454   8.345454   8.372727
#  8.381818   8.4        8.418181   8.436363   8.445455   8.463636
#  8.481818   8.490909   8.509091   8.527273   8.545455   8.554545
#  8.554545   8.554545   8.563637   8.618182   8.618182   8.645454
#  8.663636   8.672728   8.681818   8.690909   8.709091   8.718182
#  8.736363   8.745455   8.754545   8.763637   8.763637   8.772727
#  8.781818   8.790909   8.8        8.809091   8.818182   8.827272
#  8.818182   8.827272   8.827272   8.836364   8.836364   8.836364
#  8.854546   8.854546   8.854546   8.854546   8.863636   8.863636
#  8.863636   8.872727   8.872727   8.863636   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.881818   8.881818   8.881818
#  8.881818   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.881818   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.881818
#  8.881818   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.881818   8.881818   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.881818   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.881818
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.881818   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.881818   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.881818   8.881818   8.872727
#  8.872727   8.872727   8.872727   8.881818   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.881818   8.881818   8.881818
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.881818   8.872727   8.881818   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.881818   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.881818
#  8.881818   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.881818   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.881818   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.881818   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727   8.872727   8.872727
#  8.872727   8.872727   8.872727   8.872727  ]

# %% [markdown]
# export data to exel

# %%
import pandas as pd

# %%
print(len(l_array))
# Out:
# 916

# %%
data = []
num_img = 2217
for i in range(len(l_array)):
    data.append(( " 10.15.2020 (1) " + str(num_img + i).zfill(4)  ,l_array[i] )) 
# print(data)
dataframe = pd.DataFrame(data, 
             columns=['image_name', 
                      'length(cm)'])
# print(dataframe)
# writing to Excel
datatoexcel = pd.ExcelWriter('Heptanewater-80-20(1)_10.15.2020_1-45-02-PM.xlsx')
# write DataFrame to excel 
dataframe.to_excel(datatoexcel)
#save the excel
datatoexcel.save()

# %%
dataframe.plot(kind='line',x='image_name',y='length(cm)',color='red')
plt.show()
